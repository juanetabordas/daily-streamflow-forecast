# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import xarray as xr
import matplotlib.pyplot as plt
from Funciones import *

# %%
ruta_base  = os.path.dirname(os.path.abspath('./')) + '/'
ruta_datos = ruta_base + 'Datos/'
ruta_shp   = ruta_datos+ 'Shapefiles/'

# %% [markdown]
# ### Series de precipitación

# %%
ruta_ppt = ruta_datos + 'Originales/PPT/'
files = glob.glob(ruta_ppt+'*')

# %%
files
# Out:
# ['/mnt/g/My Drive/Maestría en Recursos Hidraulicos/IA y AU en geociencias/Trabajo/Datos/Originales/PPT/PPT_NSA_ERA5_2001-2020.nc',
#  '/mnt/g/My Drive/Maestría en Recursos Hidraulicos/IA y AU en geociencias/Trabajo/Datos/Originales/PPT/PPT_NSA_IMERG_2001-2020.nc']

# %%
names_ppt = []
data_ppt  = []

for file in files:
    name = file.split('/')[-1].split('.')[0].split('_')[2]
    data   = xr.open_dataset(file)
    lat    = np.array(data['lat'])
    lon    = np.array(data['lon'])
    ppt    = np.array(data['ppt'])

# %% [markdown]
# ### Caudal

# %%
ruta_caudal = ruta_datos + 'Originales/Caudal/'
files = glob.glob(ruta_caudal+'*.csv')

# %%
names_caudales = []
data_caudales  = []
# Tablazo el el de sitio de presa en un principio
for file in files:
    name = file.split('/')[-1].split('.')[0]
    names_caudales.append(name)
    serie = pd.read_csv(file, index_col=0)
    serie = serie['Valor'][serie['Unnamed: 2']==51.0]
    serie.index = pd.DatetimeIndex(serie.index)
    serie = serie.resample('d').mean()['2000':]
    data_caudales.append(serie.values)
    plt.figure(figsize=(10,4))
    serie.plot()
    plt.title(name)
    plt.show()
    plt.close('all')

# %%
# Tablazo el el de sitio de presa en un principio

file = files[0]
name = file.split('/')[-1].split('.')[0]
serie = pd.read_csv(file, index_col=0)
serie = serie['Valor'][serie['Unnamed: 2']==51.0]
serie.index = pd.DatetimeIndex(serie.index)
serie = serie.resample('d').mean()['2000':]
plt.figure(figsize=(10,4))
serie.plot()
plt.title(name)
plt.show()
plt.close('all')

# %%
caudal = pd.DataFrame(index = serie.index.values, data=serie.values, columns=['Caudal'])

# %% [markdown]
# ### Series de ondas

# %%
ruta_ondas = ruta_datos + 'Originales/Ondas/'
files = glob.glob(ruta_ondas+'*')

# %%
names_ondas = []
data_ondas  = []

region = [(-76,8),(-70,8),(-70,3),(-78,3)]
for file in files:

    name   = file.split('/')[-1].split('.')[0].split('_')[0]
    data   = xr.open_dataset(file)
    lat    = np.array(data['lat'])
    lon    = np.array(data['lon'])
    time   = pd.DatetimeIndex(np.array(data['time']))
    data_s = np.array(data['olr_s'])
    data_a = np.array(data['olr_a'])

    for data_i, i in zip([data_s, data_a],['s','a']):
        names_ondas.append(name+'_'+i)
        data_ondas.append(Serie_Cuenca_P(Polygon_Generator(region,[]), Data=data_i, Latitudes=lat, Longitudes=lon, Fechas=time).values)

fechas = pd.DatetimeIndex(Serie_Cuenca_P(Polygon_Generator(region,[]), Data=data_i, Latitudes=lat, Longitudes=lon, Fechas=time).index)

ondas = pd.DataFrame(index=fechas, data = np.array(data_ondas).T, columns=names_ondas)
# Out:
# /mnt/g/My Drive/Maestría en Recursos Hidraulicos/IA y AU en geociencias/Trabajo/Scripts/Funciones.py:62: RuntimeWarning: Mean of empty slice
#   mean_1 = np.nanmean(cut_data, axis=1)

# %%
ondas.drop(columns = ['EIG_s','MRG_s','WIG_a','TD_a','ER_a','Kelvin_a'], inplace=True)

# %%
ondas
# Out:
#                 EIG_a      ER_s   Kelvin_s     MJO_s     MJO_a     MRG_a  \
# 2001-02-02   3.472839 -2.538527   4.060272 -4.581935 -0.699003  1.043384
# 2001-02-03  -0.933801 -1.033567  -1.525076 -4.702835 -0.704193 -2.067537
# 2001-02-04  -2.512747  0.587908  -4.572494 -4.697544 -0.693261 -1.375889
# 2001-02-05   2.848997  1.901652  -4.984876 -4.565582 -0.665588  3.258563
# 2001-02-06  -1.166517  2.592392  -2.904190 -4.310416 -0.621030  3.303734
# ...               ...       ...        ...       ...       ...       ...
# 2020-11-16  -0.807936  5.253497 -10.202110  1.540721 -0.178269 -1.041809
# 2020-11-17   1.727120  7.120134 -14.783565  1.128295 -0.022558 -1.260204
# 2020-11-18  -2.296233  7.695562   1.356259  0.699870  0.127739  0.155920
# 2020-11-19  -4.791578  7.079211  11.807167  0.269720  0.268386  1.982399
# 2020-11-20  11.279375  5.598405  -4.531323 -0.148249  0.395595  1.406232
#
#                 TD_s     WIG_s
# 2001-02-02 -4.896246  3.619513
# 2001-02-03  0.859960 -3.188267
# 2001-02-04  3.592543  2.471776
# 2001-02-05 -2.351354 -1.794038
# 2001-02-06  0.447085  1.261962
# ...              ...       ...
# 2020-11-16  1.241732 -2.408803
# 2020-11-17  4.980706  2.914153
# 2020-11-18  0.336406 -2.658446
# 2020-11-19  0.526290  1.975691
# 2020-11-20 -5.468555 -1.004800
#
# [7232 rows x 8 columns]

# %%
ondas.plot(subplots=True, figsize=(10,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
print(lat)
print(lon)
# Out:
# [ 15.   12.5  10.    7.5   5.    2.5   0.   -2.5  -5.   -7.5 -10. ]
# [-90.  -87.5 -85.  -82.5 -80.  -77.5 -75.  -72.5 -70.  -67.5 -65.  -62.5
#  -60.  -57.5 -55.  -52.5 -50.  -47.5 -45.  -42.5 -40. ]

# %% [markdown]
# ### Cargando Chorros

# %%
ruta_chorros = ruta_datos + 'Originales/Chorros/'
files = glob.glob(ruta_chorros+'*')

# %%
names_chorros = []
data_chorros  = []

for file in files:
    names_chorros.append(file.split('/')[-1].split('.')[0])
    data_chorros.append(pd.read_csv(file, index_col=0).values)
    
fechas = pd.DatetimeIndex(pd.read_csv(file, index_col=0).index)

chorros = pd.DataFrame(index=fechas, data = np.concatenate(data_chorros, axis=1), columns=names_chorros)

# %%
chorros.plot(subplots=True, figsize = (10,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
pd.plotting.scatter_matrix(chorros, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='CARIBE_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CARIBE_u'>],
#        [<AxesSubplot:xlabel='CARIBE_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CARIBE_v'>],
#        [<AxesSubplot:xlabel='CARIBE_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CHOCO_u'>],
#        [<AxesSubplot:xlabel='CARIBE_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CHOCO_v'>],
#        [<AxesSubplot:xlabel='CARIBE_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='ORINOQUIA_u'>],
#        [<AxesSubplot:xlabel='CARIBE_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='ORINOQUIA_v'>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(ondas, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='EIG_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='EIG_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='ER_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='Kelvin_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MJO_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MJO_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MRG_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='TD_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='WIG_s'>]], dtype=object)

# %%
ondas_chorros_caudal = pd.concat((ondas,chorros,caudal), axis=1)

# %%
pd.plotting.scatter_matrix(ondas_chorros_caudal, figsize=(15,15))
# Out:
# array([[<AxesSubplot:xlabel='EIG_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='EIG_a'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='EIG_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='ER_s'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='ER_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='Kelvin_s'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='Kelvin_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='MJO_s'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='MJO_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='MJO_a'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='MJO_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='MRG_a'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='MRG_a'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='TD_s'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='TD_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='WIG_s'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='WIG_s'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CARIBE_u'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='CARIBE_u'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CARIBE_v'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='CARIBE_v'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CHOCO_u'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='CHOCO_u'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='CHOCO_v'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='CHOCO_v'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='ORINOQUIA_u'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='ORINOQUIA_u'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='ORINOQUIA_v'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='ORINOQUIA_v'>],
#        [<AxesSubplot:xlabel='EIG_a', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='ER_s', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='Kelvin_s', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='MJO_s', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='MJO_a', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='MRG_a', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='TD_s', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='WIG_s', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='CARIBE_u', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='CARIBE_v', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='CHOCO_u', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='CHOCO_v', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='ORINOQUIA_u', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='ORINOQUIA_v', ylabel='Caudal'>,
#         <AxesSubplot:xlabel='Caudal', ylabel='Caudal'>]], dtype=object)

# %%
ondas_chorros_caudal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8306 entries, 2000-01-01 to 2022-09-27
# Freq: D
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EIG_a        7232 non-null   float64
#  1   ER_s         7232 non-null   float64
#  2   Kelvin_s     7232 non-null   float64
#  3   MJO_s        7232 non-null   float64
#  4   MJO_a        7232 non-null   float64
#  5   MRG_a        7232 non-null   float64
#  6   TD_s         7232 non-null   float64
#  7   WIG_s        7232 non-null   float64
#  8   CARIBE_u     7305 non-null   float64
#  9   CARIBE_v     7305 non-null   float64
#  10  CHOCO_u      7305 non-null   float64
#  11  CHOCO_v      7305 non-null   float64
#  12  ORINOQUIA_u  7305 non-null   float64
#  13  ORINOQUIA_v  7305 non-null   float64
#  14  Caudal       7573 non-null   float64
# dtypes: float64(15)
# memory usage: 1.0 MB
