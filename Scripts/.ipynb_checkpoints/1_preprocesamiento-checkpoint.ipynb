# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import xarray as xr
import matplotlib.pyplot as plt
import datetime as dt
from Funciones import *

# %%
ruta_base  = os.path.dirname(os.path.abspath('./')) + '/'
ruta_datos = ruta_base + 'Datos/'
ruta_shp   = ruta_datos+ 'Shapefiles/'

# %%
datos = pd.read_csv(ruta_datos+'Datos.csv', index_col=0, parse_dates=True)

# %%
datos.plot(subplots=True, figsize=(10,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %% [markdown]
# ### Climatologías

# %%
media_climatologica = datos.groupby([datos.index.month, datos.index.day]).mean()
# arreglar el 29 de febrero
media_climatologica.loc[2, 29, :] = (media_climatologica.loc[2, 28, :].values+media_climatologica.loc[3, 1, :].values)/2

# %%
media_climatologica.to_csv(ruta_datos+'Media_clima_datos.csv')

# %%
media_climatologica.plot(subplots=True, figsize=(10,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
std_climatologica = datos.groupby([datos.index.month, datos.index.day]).std()
# arreglar el 29 de febrero
std_climatologica.loc[2, 29, :] = (std_climatologica.loc[2, 28, :].values+std_climatologica.loc[3, 1, :].values)/2

# %%
std_climatologica.to_csv(ruta_datos+'Std_clima_datos.csv')

# %%
std_climatologica.plot(subplots=True, figsize=(10,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %% [markdown]
# ### Anomalíás estandarizadas

# %%
datos.groupby([datos.index.month, datos.index.day])

# %%
def Estandarizar(serie, media, std):
    
    serie_anom = serie.copy()
    
    for index in media_climatologica.index.to_numpy():
        
        serie_anom[(serie_anom.index.month==index[0])&(serie_anom.index.day==index[1])] = \
        (serie_anom[(serie_anom.index.month==index[0])&(serie_anom.index.day==index[1])] - media[index[0],index[1]])/std[index[0],index[1]]
        
        print(serie_anom[(serie_anom.index.month==index[0])&(serie_anom.index.day==index[1])])
        
    return serie_anom

# %%
Estandarizar(datos['Caudal'], media_climatologica['Caudal'], std_climatologica['Caudal'])
# Out:
# 2000-01-01    1.745479
# 2001-01-01    0.283434
# 2002-01-01    0.057606
# 2003-01-01   -0.762647
# 2004-01-01   -0.394051
# 2005-01-01   -0.114685
# 2006-01-01   -0.644555
# 2007-01-01   -0.327514
# 2008-01-01    0.412982
# 2009-01-01    1.146318
# 2010-01-01   -1.094229
# 2011-01-01         NaN
# 2012-01-01         NaN
# 2013-01-01   -1.547061
# 2014-01-01   -0.589326
# 2015-01-01   -0.555215
# 2016-01-01   -0.689941
# 2017-01-01    2.071663
# 2018-01-01    0.082722
# 2019-01-01   -1.153715
# 2020-01-01    0.186514
# 2021-01-01    1.929660
# 2022-01-01   -0.043440
# Name: Caudal, dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_82/1911193089.py in <module>
# ----> 1 Estandarizar(datos['Caudal'], media_climatologica['Caudal'], std_climatologica['Caudal'])
#
# /tmp/ipykernel_82/3636686689.py in Estandarizar(serie, media, std)
#       8
#       9         print(serie_anom[(serie_anom.index.month==index[0])&(serie_anom.index.day==index[1])])
# ---> 10         aaa
#      11
#      12     return serie_anom
#
# NameError: name 'aaa' is not defined

# %%
datos['Caudal']
# Out:
# 2000-01-01     371.180000
# 2000-01-02     312.920000
# 2000-01-03     324.250000
# 2000-01-04     287.020000
# 2000-01-05     377.660000
#                  ...
# 2022-09-23     635.086997
# 2022-09-24    1034.180552
# 2022-09-25    1084.806071
# 2022-09-26     538.911729
# 2022-09-27     468.664910
# Name: Caudal, Length: 8306, dtype: float64
